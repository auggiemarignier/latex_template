# %% [markdown]
# # Figure Exploration
#
# Use this notebook to play around with and develop figures.  Canonical/reproducible figure generation should be done in individual scripts in `scripts`.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import scienceplots

plt.style.use("science")

DATA_PATH = Path().resolve().parent / "data"
